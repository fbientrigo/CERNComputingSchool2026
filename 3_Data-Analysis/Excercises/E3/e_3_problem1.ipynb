# %% [markdown]
# # Problem 1

# %%
import numpy as np

# %%
data = np.loadtxt('LHC_data_2021.txt', delimiter=',')

len(data)
# Out:
# 10000

# %%
print("data its in the range",data.min(),",",data.max())
# Out:
# data its in the range 20.0 , 40.0
